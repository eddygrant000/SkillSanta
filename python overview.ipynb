# %% [markdown]
# # This is my first programmes

# %%
print("hi all from sachin")
# Out:
# hi all from sachin

# %%
print("hi ")
print("bye")
a = 10
b = 20
print(a + b)
# Out:
# hi
# bye
# 30

# %%
print('hello world!')
# Out:
# hello world!
